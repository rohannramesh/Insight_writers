# %%
import numpy as np
from IPython.core.debugger import set_trace
import re
import difflib
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import time
import random
import pickle
from lxml.html import fromstring
from collections import Counter
from requests.packages.urllib3.util import Retry
from requests.adapters import HTTPAdapter
from requests import Session, exceptions
import sys
import pymongo
from pymongo import MongoClient
from newspaper import Article
import json

# %%
# data load
with open('/Users/rohanramesh/Documents/Insight/data_bball_writers/Attempt3_mr_scrape.pickle', 'rb') as handle:
    scrapevar = pickle.load(handle)

# %%
scrapevar.keys()
# Out:
# dict_keys(['pubdates', 'sources', 'blurbs', 'links', 'titles'])

# %%
all_sources = []
for curr_name in scrapevar['sources']:
    for curr_source in scrapevar['sources'][curr_name]:
        all_sources.append(curr_source)

# %%
len(all_sources)
# Out:
# 16896

# %%
source_counts = Counter(all_sources)
df = pd.DataFrame.from_dict(source_counts, orient='index')
col = list(df)

# %%
# Plot top 10 number of articles
a = df.sort_values(by=col[0],ascending=False)
name_sites_sorted = list(a[0].index)
narticles_sites_sorted = list(a[0].values)
nplot = 10
plt.bar(name_sites_sorted[0:nplot], narticles_sites_sorted[0:nplot], align='center')
plt.xticks(rotation=60)
plt.ylabel('Number of articles')
# Out:
# Text(0,0.5,'Number of articles')

# %%
# get_proxies():
def get_proxies(nprox):
    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    curr_soup = BeautifulSoup(response.text)
    rand_ipadd = []
    alllist = curr_soup.findAll("tr")
    # alllist[1].next.text
    rvec = random.sample(range(1, 15), nprox)
    for i in rvec:
        rand_ipadd.append((alllist[i].next.text + ":" + alllist[i].next.next.next.text))
    return rand_ipadd

def get_user_agents(nagents):
    useragent_add = 'https://developers.whatismybrowser.com/useragents/explore/software_type_specific/web-browser/'
    page = requests.get(useragent_add)
    curr_soup = BeautifulSoup(page.text)
    rand_useragents = []
    alllist = curr_soup.findAll("td", {"class": "useragent"})
    rvec = random.sample(range(0, 25), nagents)
    for i in rvec:
        a = alllist[i].find("a")
        rand_useragents.append(a.text)
    return rand_useragents

def build_proxy_agent(proxy_list,user_agent_list):
    proxy = random.choice(proxy_list)
    http_proxy  = "http://" + proxy
    https_proxy = "https://" + proxy

    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy
                }
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    return proxyDict, headers

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

# %%
proxy_list = get_proxies(12)
user_agent_list = get_user_agents(12)

# %%
# grabbing article fn
def grab_espn_article(curr_name,link_idx):
    article_url = scrapevar['links'][curr_name][link_idx]
    article_source = scrapevar['sources'][curr_name][link_idx]
    article_pubdate = scrapevar['pubdates'][curr_name][link_idx]
    page = requests_retry_session(retries=10).get(
        article_url, timeout=10)
    curr_soup = BeautifulSoup(page.text)
    textcontainer = curr_soup.find("article", {"class": "article"})
    textsection = textcontainer.find("div", {"class": "article-body"})
    pgraphs = textsection.findAll("p")
    alltext = ''
    for i in pgraphs:
        alltext = alltext + i.text + ' '
    return article_url, article_source, article_pubdate, alltext

# grab relevant information for article
def grab_article_info(curr_name,link_idx):
    article_url = scrapevar['links'][curr_name][link_idx]
    article_source = scrapevar['sources'][curr_name][link_idx]
    article_pubdate = scrapevar['pubdates'][curr_name][link_idx]
    return article_url, article_source, article_pubdate

# %%
# scraping with Newsweek
article_url = scrapevar['links']['zachlowe_nba'][6]
article = Article(article_url)
article.download()
article.parse()
article.text
# Out:
# 'Jalen Rose likes the Kawhi Leonard trade for DeMar DeRozan because it gives both San Antonio and Toronto a chance to improve. (1:19)\n\nAt the end of a mid-December practice last season, the five highest-ranking members of Toronto\'s brain trust called DeMar DeRozan into the office of Masai Ujiri, Toronto\'s president of basketball operations, for something of an intervention.\n\n"I didn\'t know what the hell was going on," DeRozan told ESPN a few months later. "I thought, \'S---, I know I can\'t be traded.\' It was like I was being called into the principal\'s office."\n\nUjiri told DeRozan he could be Toronto\'s Kobe Bryant -- a lifetime superstar carrying his team toward title contention -- if he cleared the last hurdle in his game: shooting more 3s. DeRozan started chucking over Toronto\'s next few games, and the Raptors hummed to 59 wins. The story appeared to have ended happily.\n\nBut the team never reached title contention. LeBron humiliated them again. DeRozan was decent in Games 1 and 2 of their second-round series before vanishing in Cleveland. He finished the series 0-of-9 from deep. He spent the fourth quarter of Game 3, his last meaningful game playing for a team and city he grew to love and that loved him back, on the bench as the Raptors rallied (but still lost) without him.\n\nNow DeRozan is a Spur, a centerpiece of the Kawhi Leonard anticlimax -- a deal that can work for Toronto both as a means to that elusive Finals berth and the first step toward a complete teardown.\n\nThe price was low: DeRozan, Jakob Poeltl, and a top-20 protected first-round pick that converts into two 2020 second-round picks if it somehow lands in the top 20 this season.\n\nThe Spurs lost some leverage when LeBron James opted out of his deal with Cleveland, and lost more when he joined the Lakers without issuing any immediate mandates about superstar partners. They were going to lose a little more every day until training camp.\n\nThey didn\'t start with much, either. Nobody knows if Leonard is healthy enough to regain status as a top-five player and MVP candidate. (He still has to pass a physical.) Suitors feared his impending free agency, and his reported preference for one of the L.A. teams. NBA free agency and trades! Here\'s the latest on another thrilling summer in the NBA: • Offseason grades: Best in the West\n\n• Free-agency news, buzz and rumors\n\n• NBA Trade Machine: Make your own deals\n\n• Lowe: Winners and losers | Rating the deals\n\n• Details on each new free-agent contract\n\n• Team-by-team free agents for \'18 and \'19\n\n• Trade tracker: Grades and details\n\n• World of Woj: Latest news | Transactions\n\nHis camp made it very clear over the past week, to the Raptors and other teams, that Leonard wanted no part of Toronto, sources say.\n\nThe Raptors didn\'t care. They know any threat of failing to report is probably empty, since they can fine Leonard for each practice and game he misses -- up to his full $20.1 million salary.\n\nUjiri will certainly try to sway Leonard on the trappings of a diverse city a little outside the limelight, with an insane (in the very best way) fan base. He will have to do the heavy lifting, because that is too much to ask of a first-year head coach in Nick Nurse. Ujiri has a charisma, and a way with players. A Finals run might help. Toronto has a chance at that. With this deal, the Raptors enter next season just behind Boston -- ahead of Philly -- in the Eastern Conference pecking order. (The Celtics could be 60-plus-wins special next season.)\n\nIf Toronto gets the sense by Thanksgiving that Leonard is leaving regardless, it can try to flip him to the Lakers or Clippers. The Raptors won\'t make themselves whole in such a deal, but they could recoup enough of what they traded as to make today\'s move almost risk-free.\n\nIf Leonard walks for nothing, the full rebuild is on. Toronto is clearly fine shedding the final two guaranteed years of DeRozan\'s contract, at $27.7 million a pop, and ...

# %%
sys.getsizeof(article)
# Out:
# 56

# %%
article2 = grab_espn_article('zachlowe_nba',6)
sys.getsizeof(article2)
# Out:
# 80

# %%
# attempt to pull espn article
article_url = scrapevar['links']['kevin-arnovitz'][6]
page = requests_retry_session(retries=10).get(
    article_url, timeout=10)
curr_soup = BeautifulSoup(page.text)
textcontainer = curr_soup.find("article", {"class": "article"})
textsection = textcontainer.find("div", {"class": "article-body"})
pgraphs = textsection.findAll("p")
alltext = ''
for i in pgraphs:
    alltext = alltext + i.text + ' '
print(alltext)
# Out:
# The Grizzlies can't -- and probably won't -- get pummeled on the glass as they did in Game 1. The Glass Finding signs of encouragement after a 21-point loss can be like leading a search party in the dark, but if the Grizzlies are looking for some reassurance, it should come in the near certainty that they won’t be outrebounded again by a 2-to-1 margin. If that seemed unprecedented, that's because it was. Memphis didn't come anywhere close to a margin like that in any game during the regular season. There’s a general belief that rebounding doesn’t slump in the NBA. A team like the Grizzlies, which dominated the boards in the regular season (second in overall rebounding rate), doesn’t forget how to ply its trade. Short of injury or a deliberate strategy like a zone defense or fronting the post -- tactics that can make it harder to crash the glass -- a debacle such as Saturday night's is an outlier. The Grizzlies better hope so. They’re not a team endowed with much perimeter firepower or natural athleticism. They win basketball games by controlling possessions, something they simply can’t accomplish if the Clippers are collecting 42 percent of their misses. The Point God Chris Paul exerts an element of control over a basketball game that’s uncanny, and this hasn't been news in ages. What’s more interesting to observe is how he manages his role within the emotional and strategic contours of that game, not unlike LeBron James, in a sense. Is Paul creating for others, or hunting shots for himself? Is he conserving energy off the ball, or is he in Probe Mode? On Saturday night, the answer was all of the above, and that’s really where Paul needs to be for the Clippers to achieve their full potential as an offensive club. We saw some new wrinkles to the Clippers’ half-court game, with Paul not exclusively an initiator but also a scorer. He came off screens for live-ball catches in a couple of inventive sets, the kind of stuff we haven’t always seen from the Clippers. But Paul also claimed several possessions for himself to test the mobility of the Memphis big men. For Memphis, the pick-and-roll coverage has to improve, and the Grizzlies know that. They’re an exceptionally well-prepared group that’s completely devoted to the execution of a very intelligent defensive system. Grizzlies  coach Lionel Hollins and several players laid it out Sunday at practice. “The guards have to do a better job of pushing up on the ball handlers,” Mike Conley said. “They were flipping the screens, so our big would show one way, but then their big would flip the screen and Chris would see it. I’d run into the screen pretty good and he’d get a full head of steam on our big man, and you can’t guard him when he’s got a full head of steam with the confidence he has in the paint.” A defense might not be able to take away Paul’s confidence, but it can take away some real estate. The Gamble OK, so who’s going to defend Paul? A tough question because there’s no entirely satisfying answer. In Game 1, Hollins opted for Conley. This wasn’t an unreasonable conclusion. Conley did an acceptable job of checking Paul during last year’s playoff series. Paul certainly created some quality shots, but he worked for just about everything and spent a fair amount of time in spots on the floor where he had no interest being. But on Saturday, it wasn’t just that Paul got where he wanted to go, but that he got there in such little traffic. As Blake Griffin said, there was something extremely un-Grizzly about the Clippers' "getting what they wanted," and it can largely be attributed to the little resistance encountered by Paul. The obvious alternative would be to stick Tony Allen on Paul, but that presents other risks, such as Chauncey Billups dragging Conley into the post. We saw Billups draw Conley on a switch in Game 1 and then promptly back Conley down before draining an easy midrange shot over him. There are no good choices for guarding Paul, but that might be a risk the Grizzli ...

# %%
# for theringer.com
article_url = scrapevar['links']['jason-concepcion'][6]
print(article_url)
proxyDict, headers = build_proxy_agent(proxy_list,user_agent_list)
page = requests_retry_session(retries=10).get(
                article_url, headers=headers, proxies=proxyDict, timeout=10)
curr_soup = BeautifulSoup(page.text)
textsection = curr_soup.find("div", {"class": "c-entry-content"})
pgraphs = textsection.findAll("p")
alltext = ''
for i in pgraphs:
    alltext = alltext + i.text + ' '
print(alltext)
# Out:
# https://www.theringer.com/binge-mode/2018/9/3/17813820/harry-potter-and-the-order-of-the-phoenix-ch-24-28
# Hello! (Yeah!) And welcome to Binge Mode! Mallory Rubin and Jason Concepcion continue their exploration of the Harry Potter universe by diving deep into Harry Potter and the Order of the Phoenix, chapters 24 through 28. To help guide you on that journey, here is a map of the 30th episode of Binge Mode: Harry Potter. It’s not quite as detailed as the Marauder’s Map, but don’t fear: The podcast is just as magical. On Tuesday, Mallory and Jason return for Episode 31 of Binge Mode: Harry Potter, in which they will break down chapters 29 through 33 of Order of the Phoenix. For the full podcast, subscribe on Apple Podcasts, Stitcher, Spotify, or wherever you get podcasts, and follow along on Twitter and join the Facebook group, which is just for Binge Mode fans. We await your digital Owl Post!

# %%
for curr_name in scrapevar['sources']:
    for curr_source in scrapevar['sources'][curr_name]:
        if curr_source == 'bleacherreport.com':
            print(curr_name)
# Out:
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# zachlowe_nba
# lee-jenkins
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# howardbeck
# kevin-arnovitz
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# tom-haberstroh
# brian-windhorst
# brian-windhorst
# brian-windhorst
# brian-windhorst
# brian-windhorst
# david-aldridge
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# ramona-shelburne
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# jpdabrams
# marc-j-spears
# marc-j-spears
# marc-j-spears
# marc-j-spears
# marc-j-spears
# marc-j-spears
# marc-j-spears
# chris-haynes
# chris-haynes
# chris-haynes
# chris-haynes
# robmahoney
# tim-macmahon
# chris-herring
# chris-herring
# jonathan-tjarks
# chris-mannix
# chris-mannix
# chris-mannix
# chris-mannix
# chris-mannix
# chris-mannix
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# michael-pina
# scott-rafferty
# alex-kennedy
# alex-kennedy
# alex-kennedy
# alex-kennedy
# alex-kennedy
# alex-kennedy
# alex-kennedy
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# ericpincus
# seerat-sohi
# seerat-sohi
# seerat-sohi
# seerat-sohi
# israel-gutierrez
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# ken-berger
# neil-paine
# sam-amico
# michael-grange
# michael-grange
# michael-grange
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# jared-zwerling
# noah-torr
# noah-torr
# noah-torr
# noah-torr

# %%
# for yahoo sports
article_url = scrapevar['links']['shams-charania'][-1]
print(article_url)
proxyDict, headers = build_proxy_agent(proxy_list,user_agent_list)
page = requests_retry_session(retries=10).get(
                article_url, headers=headers, proxies=proxyDict, timeout=10)
curr_soup = BeautifulSoup(page.text)
textsection = curr_soup.find("article")
pgraphs = textsection.findAll("p")
alltext = ''
for i in pgraphs:
    alltext = alltext + i.text + ' '
print(alltext)
# Out:
# https://sports.yahoo.com/sources-troy-williams-agrees-two-year-deal-knicks-200853056.html
# The New York Knicks and forward Troy Williams have agreed to a two-year contract, league sources told Yahoo Sports. Williams’ deal will be guaranteed for the remainder of this season and includes partial guarantees for next season, league sources said. Play Tourney Pick’em | Play against Draymond Green  | Print bracket | What you need to know Williams, an athletic 6-foot-7 wing, has averaged 8.1 points and 2.9 rebounds in 13.9 minutes per game in eight appearances for the Knicks. His second 10-day contract with the team expired on Monday, and the Knicks worked with Williams’ agent, Stephen Pina, to finalize a deal to keep the 23-year-old from entering the offseason as a free agent. Williams is in his second NBA season after going undrafted in 2016 out of Indiana. He joined the Knicks after being released by the Houston Rockets to create roster space for Joe Johnson. More from Yahoo Sports:  • Did a Lakers usher really not recognize Jack Nicholson? • How the NCAA’s mistake could lead to historic tourney upset • Heartbreaking photo shows sad side of March Madness • Short deal for QB Cousins could go long way for elite NFL platyers

# %%
# for si.com
article_url = scrapevar['links']['ben-golliver'][1]
print(article_url)
proxyDict, headers = build_proxy_agent(proxy_list,user_agent_list)
page = requests_retry_session(retries=10).get(
                article_url, headers=headers, proxies=proxyDict, timeout=10)
curr_soup = BeautifulSoup(page.text)
textsection = curr_soup.find("div", {"id": "article-body"})
if not textsection:
    textsection = curr_soup.find("div", {"id": "longform-body"})
pgraphs = textsection.findAll("p")
alltext = ''
for i in pgraphs:
    alltext = alltext + i.text + ' '
print(alltext)
# Out:
# https://www.si.com/nba/2018/09/10/top-100-nba-players-2019-lebron-james-stephen-curry-dirk-nowitzki
# The Crossover is proud to offer our list of the Top 100 NBA players of 2019, an exhaustive exercise that seeks to define who will be the league's best players in the 2018-19 season. Given the wide variety of candidates involved and the deep analytical resources available, no single, definitive criterion was used to form this list. Instead, rankings were assigned based on a fluid combination of subjective assessment and objective data. This list is an attempt to evaluate each player in a vacuum, independent of his current team context as much as possible. A player's prospects beyond the 2018-19 season did not play a part in the ranking process. Injuries and injury risks are an inevitable component of this judgment. Past performance (postseason included) weighed heavily in our assessment, with a skew toward the recent. First-year players were not included. A predictive element also came into play with the anticipated improvement of certain younger players, as well as the possible decline of aging veterans. Salary was not taken into consideration. Otherwise, players were ordered based on their complete games. You can read more here on the limitations of this kind of ranking. To see our 25 biggest snubs from this year, click here. Please feel free to look back to SI.com’s Top 100 Players of 2018, 2017, 2016, 2015 and 2014. A special thanks, as always, to those resources that make researching a list like this possible: Basketball-Reference, NBA.com, ESPN.com, Cleaning the Glass, and Synergy Sports.     Ball (10.2 PPG, 6.9 RPG, 7.2 APG) was the league’s easiest target last season: He faced significant pressure as the No. 2 pick, he faced extra scrutiny on a high-profile franchise that had one eye on LeBron James, he faced derision for his unsightly jumper and fading confidence, and he faced second-hand disdain thanks to the ramblings of his infamous father and his immature brother. “Baptism by Fire” would be an appropriate name for a documentary about his first season, which began with Patrick Beverley eating him for dinner and ended with knee problems that ultimately required summer surgery. At his best, the 20-year-old Ball plays a beautiful weirdo brand of hoops that would merit a full
many of his team’s pursuits. The Pacers may have been the best story of last season and Young, impressively, their second-best player. — RM     Even though Magic Johnson scooped up virtually every available wild card in free agency, the Lakers’ biggest X-factor remains Ingram (16.1 PPG, 5.3 RPG, 3.9 APG). The 2016 No. 2 pick made clear strides in his second season, emerging as a full-time starter, ratcheting up his scoring and efficiency, improving as a finisher, and becoming more comfortable and less predictable with the ball in his hands. At times, Ingram brought to life the pre-draft projections that he would be a perennial All-Star wing: he displayed the handle and shake necessary to create good shots, he attacked the basket more assertively, and he deployed his spindly length to find seams through the defense and exploit size mismatches. The surest way for the new-look Lakers to make noise in the playoffs would be for Ingram to establish himself as a reliable No. 2 scoring option and a plus defender. To get there, he must continue to extend his range, engage his attack mode with greater consistency, and play more disruptively on the defensive end. He also needs better health, as he was sidelined for a quarter of L.A.’s 2017-18 season. LeBron James’s arrival, of course, should make his life easier: Ingram will face more favorable defensive matchups, receive cleaner catch-and-shoot looks, and play within a more structured and explosive style. After two seasons getting his bearings, it’s time for Ingram’s training wheels to come off for good. — BG     While Wiggins (17.7 PPG, 4.4 RPG, 2.0 APG) has been guilty of playing some of the NBA’s emptiest minutes, he sure does play a lot of them. Indeed, the 2014 No. 1 overall pick has logged a league-leading 11,841 minutes and missed just one game over the last four years. Instead of using that tremendous developmental opportunity as a ramp to superstardom, the 23-year-old wing  ...

# %%
# for fansided.com
article_url = scrapevar['links']['nick-sciria'][1]
print(article_url)
proxyDict, headers = build_proxy_agent(proxy_list,user_agent_list)
page = requests_retry_session(retries=10).get(
                article_url, headers=headers, proxies=proxyDict, timeout=10)
curr_soup = BeautifulSoup(page.text)
textsection = curr_soup.findAll("section", {"class": "article-content"})
alltext = ''
for currsection in textsection:
    pgraphs = currsection.findAll("p")
    for i in pgraphs:
        alltext = alltext + i.text + ' '
    print(alltext)
# Out:
# https://fansided.com/2017/08/29/nylon-calculus-examining-kyrie-irving-celtics-role/
# Sometimes, the allure of changing scenery can turn out to be nothing more than a hoax. The newness and unfamiliarity that once seemed so appealing unfolds into the same hidden conflicts and particularly unique challenges of old. However, Kyrie Irving’s new home provides him with a distinctly new world of values and responsibilities, features that could make Irving’s change of scenery well worth it. To demonstrate this difference, let’s compare Kyrie Irving with former Celtics point guard Isaiah Thomas. Despite fairly similar skillsets, an unmistakable contrast emerges when analyzing their respective responsibilities on the offensive end last season. Brad Stevens is, of course, at the heart of this calculated approach, and his creativity has been key in helping Thomas reshape his career. Under Stevens, Boston have embraced an offensive attack that revolves around quick decision making and constant fluidity. Boston averaged just 2.56 seconds per touch, the fourth-lowest mark in the NBA. Meanwhile, Irving’s Cavaliers averaged 2.90 seconds per touch, the eight-highest mark in the league. Read More: Khris Middleton thriving with help of Giannis Antetokounmpo But this difference does not necessarily mean that Irving will be forced to give up the ball more quickly than usual. When comparing their time per touch with all of the other starting point guards last season (something I will do for many of the statistics in this article), both Irving (48th percentile) and Thomas (41st percentile) were just slightly below average. However, the difference will likely be felt before Irving even receives the ball. In Boston, Thomas commonly spent a significant amount of time off of the ball. In this role, Thomas zoomed across the court, running off of a variety of screens with the hope of gaining an advantage on the defense. On the other hand, the Cavaliers were more traditional in their approach, as Irving harnessed his ball handling wizardry to jumpstart his team’s offensive attack. The differences in their off-ball movements are captured in the NBA’s speed and distance tracking shown below. Thomas embraced a “do your work early” mentality in Boston, while Irving’s off-ball role was much more relaxed in Cleveland.  And given the difference in how they were used off of the ball, it’s no surprise that this contrast trickled down to their respective play types.  Despite Thomas boasting the same gigantic scoring efficiency on isolations (1.12 points per possession) as Irving, Stevens elected to feature other parts of his point guard’s offensive game. In the Cavaliers’ offense, Irving’s isolation skills were the focal point, as he isolated more than every starting point guard except James Harden. Boston’s offense focused more on handoff situations, a tactic Stevens used to connect various actions and keep the flow of the offense intact. This play type helped Thomas thrive by allowing him to catch the ball going downhill. One of the Celtics’ favorite actions begins with Thomas in the corner, where he receives a down screen followed by a dribble handoff that usually springs him free for a 3-point shot or drive to the basket.  Off of the ball, the Celtics capitalized on Thomas’ 3-point shooting ability more than the Cavaliers did with Irving. Although Irving was more than adept in terms of spot-up success (85th percentile in the NBA), it was a much smaller part of his offensive game. And Thomas’ gravity was also used in off-ball screening situations. Take this play for example, where Thomas pitches the ball to Al Horford to initiate the offensive possession. He then gets off-ball screened twice in a matter of just a few seconds, allowing him to gain moment towards the basket, receive a pass and score.  Ultimately, the key for the Celtics will be whether or not Stevens can get Irving to buy in on the concept of using more energy off of the ball. Irving’s prospective role is likely a more taxing approach, but it can yield even more positive results in t ...

# %%
# for theathletic.com
article_url = scrapevar['links']['ethan-sherwood-strauss'][9]
print(article_url)
# proxyDict, headers = build_proxy_agent(proxy_list,user_agent_list)
# page = requests_retry_session(retries=10).get(
#                 article_url, headers=headers, proxies=proxyDict, timeout=10)
page = requests.get(article_url, timeout=10)
curr_soup = BeautifulSoup(page.text)
textsection = curr_soup.find("div", {"id": "the_paywall"})
alltext = textsection.text
print(alltext)
# Out:
# https://theathletic.com/422452/2018/07/06/steve-kerr-on-the-warriors-surprise-demarcus-cousins-coup-theres-going-to-be-a-new-dimension/
#
#
#     I spoke with Steve Kerr about the surprise DeMarcus Cousins signing, some time after Kerr was through with his sojourns up and down Interstate 5 in his son Nick’s Honda. At a point in free agency, Kerr had been called into action away from his San Diego area home and asked to help with a Los Angeles pitch meeting. Along the way, DeMarcus Cousins happened.Perhaps I shouldn’t have been surprised, but what struck me most was Kerr’s beaming enthusiasm for the addition. Professional grumps, coaches are often circumspect about even the most obviously beneficial roster moves. I anticipated more caution, more suppressing of expectations.Instead, Kerr is transparently excited about the possibilities Cousins presents and the problems he might solve. Put another way, the Warriors wish to end switching against Steph Curry as a catch-all strategy. If Cousins is healed, this defensive strategy is on the injured list.Kerr talked at length about a variety of...

# %%
# for bleacherreport.com
article_url = scrapevar['links']['howardbeck'][1]
article_source = scrapevar['sources']['howardbeck'][1]
article_pubdate = scrapevar['pubdates']['howardbeck'][1]
print(article_url)
# proxyDict, headers = build_proxy_agent(proxy_list,user_agent_list)
# page = requests_retry_session(retries=10).get(
#                 article_url, headers=headers, proxies=proxyDict, timeout=10)
page = requests.get(article_url, timeout=10)
curr_soup = BeautifulSoup(page.text)
textsection = curr_soup.find("div", {"class": "organism contentStream"})
# if not textsection:
#     textsection = curr_soup.find("div", {"id": "longform-body"})
pgraphs = textsection.findAll("p")
alltext = ''
for i in pgraphs:
    alltext = alltext + i.text + ' '
print(alltext)
# Out:
# https://bleacherreport.com/articles/2787074-gregg-popovich-steve-kerr-nba-warriors-spurs-power-50
# Steve Kerr did not set out to become an activist. Gregg Popovich did not set out to lead the NBA chapter of the resistance. Neither one has any desire to seek elected office—the #PopKerr2020 campaign notwithstanding. Yet this is where they find themselves: as leading voices for social justice, gun control and general opposition to the policies and excesses of the Donald Trump White House. As prominent, successful NBA coaches, they already had the platform. And while they might never have contemplated using that platform to advance a cause or promote a particular viewpoint, circumstances pushed them here. Gun violence. Police brutality. Racism. Nearly everything Trump has done or said since taking office. The same things that have alarmed much of the populace have caught the attention of Popovich, the San Antonio Spurs head coach, and Kerr, the Golden State Warriors head coach—both of whom are worldly, well-informed and politically astute. If the era of "stick to sports" is over, it is over at least in part because Kerr and Popovich have so boldly pushed the envelope, disregarding any potential backlash. They were willing to speak out, and that, in turn, has made it easier for more voices around the NBA to do the same. Personal experience guides both men. Popovich is an Air Force Academy graduate with a degree in Soviet studies who trained in military intelligence and has traveled the world. Kerr spent part of his childhood in Beirut, Lebanon, where his father, Malcolm, served as president of American University. When Malcolm was assassinated by Islamic terrorists in 1984, Steve was just 18 years old. So when children or concert-goers are gunned down in another mass shooting, Kerr always feels moved to speak out.  "It doesn't seem to matter to our government that children are being shot to death day after day in schools," Kerr told reporters earlier this year. "It doesn't matter that people are being shot at a concert, at a movie theater. It's not enough, apparently, to move our leadership, our government, the people running this country, to actually do anything. That's demoralizing." Popovich, too, has spoken passionately about gun control, even raising the idea that the Second Amendment should be reassessed. "Is it useful? Does it serve its purpose the way it was supposed to do in the beginning? That discussion should be had," he said in March. A month earlier, Popovich used the celebration of Black History Month to give an impassioned, impromptu locker-room speech on racism, saying, "We live in a racist country that hasn't figured it out yet, and it's always important to bring attention to it, even if it angers some people." Although both coaches have freely shared their views in the past, it was Trump's rise to power that surely helped ignite their activism. Golden State last year became the first NBA champion in recent history not to visit the White House—a direct rebuke of Trump by the players, as well as Kerr, who has referred to the president as a "blowhard" who is "unfit for office." Popovich has sounded a similar theme, blasting Trump for his "disgusting tenor and tone, and all the comments that have been xenophobic, homophobic, racist, misogynistic." In comments to The Nation last year, Popovich called Trump "a soulless coward." Such remarks might alienate a portion of the NBA fanbase. (This is certainly more likely in the Texas market, where Popovich works.) That has not dissuaded either man from speaking his conscience. In fact, the two coaches have shown more courage and commitment to justice than many elected officials, inspiring the half-joking #PopKerr2020 hashtag campaign on Twitter (which in turn inspired a line of T-shirts and coffee mugs). As flattering and amusing as that may be, neither one is ready to embrace a life in politics. "I'm not trying to run for office or do anything great," Popovich told The Undefeated. "I'm just trying to be honest with what I felt and what I think people are feeling."        ...

# %%
client = MongoClient()

# %%
db = client.test_database
collection = client.test_collection

# %%
# load writer df
with open('/Users/rohanramesh/Documents/Insight/data_bball_writers/writer_df.pickle', 'rb') as handle:
    writer_df = pickle.load(handle)

# %%
# try building mongodb
mydb = client["testinsightdb"]

# %%
# delete db
client.drop_database("testinsightdb")

# %%
# build collection for each author?
curr_name = "howardbeck"
idx = writer_df['website_name'] == curr_name
mycol = mydb[curr_name]

mydict = { "name": curr_name, "article_url": article_url, "article_source": article_source, 
         "pubdates": article_pubdate,"writer_id": writer_df['Idea ID'][idx].tolist()[0], "article": alltext}

x = mycol.insert_one(mydict)
# x = mycol.update_one({"name": curr_name},
#                      {"$set": {"article": alltext}})

# %%
# test with some zach lowe stuff
# curr_name = 'zachlowe_nba'
for curr_name in scrapevar['sources']:
    idx = writer_df['website_name'] == curr_name
    mycol = mydb[curr_name]
    rr = []
    for link_idx in range(0,len(scrapevar['links'][curr_name])):
    #     article_url, article_source, article_pubdate, alltext = grab_espn_article(curr_name,link_idx)
        article_url, article_source, article_pubdate = grab_article_info(curr_name,link_idx)
        try:
            article = Article(article_url)
            article.download()
            article.parse()
            article.text
            time.sleep(random.uniform(0.5,1.5))
            mydict = { "name": curr_name, "article_url": article_url, "article_source": article_source, 
                     "pubdates": article_pubdate,"writer_id": writer_df['Idea ID'][idx].tolist()[0], 
                      "article": article.text, "authors": article.authors, "narticle": link_idx, 
                     "article_summary": article.summary}
            x = mycol.insert_one(mydict)
    #         print(x.inserted_id)
        except Exception:
            print(curr_name + ' ' + str(link_idx))
            continue
# Out:
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2018/03/smooth_operator_dwane_casey_is_still_ironing_out_every_wrinkle_he_can_find on URL http://www.bostonherald.com/sports/celtics/2018/03/smooth_operator_dwane_casey_is_still_ironing_out_every_wrinkle_he_can_find
# lee-jenkins 25
# You must `download()` an article first!
# lee-jenkins 192
# You must `download()` an article first!
# lee-jenkins 193
# You must `download()` an article first!
# lee-jenkins 194
# You must `download()` an article first!
# lee-jenkins 195
# You must `download()` an article first!
# lee-jenkins 196
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.santafenewmexican.com/sports/for-popovich-a-second-job-comes-at-just-the-right/article_2f609d4a-33a9-586e-9649-411fa374e102.html on URL http://www.santafenewmexican.com/sports/for-popovich-a-second-job-comes-at-just-the-right/article_2f609d4a-33a9-586e-9649-411fa374e102.html
# marc-stein 10
# Article `download()` failed with 410 Client Error: Gone for url: http://www.msn.com/en-ca/sports/news/carmelo-anthony-set-to-sign-with-rockets/ar-BBKZjAO?li=AAggXBR&srcref=rss on URL http://www.msn.com/en-ca/sports/news/carmelo-anthony-set-to-sign-with-rockets/ar-BBKZjAO?li=AAggXBR&srcref=rss
# marc-stein 15
# Article `download()` failed with 410 Client Error: Gone for url: http://www.msn.com/en-ca/sports/news/with-promises-kept-lebron-james-has-choices-to-make/ar-AAyoJn3?li=AAggXBR&srcref=rss on URL http://www.msn.com/en-ca/sports/news/with-promises-kept-lebron-james-has-choices-to-make/ar-AAyoJn3?li=AAggXBR&srcref=rss
# marc-stein 65
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn.com/espn/now?nowId=21-0495635084288727957-4 on URL http://espn.go.com/espn/now?nowId=21-0495635084288727957-4
# ethan-sherwood-strauss 153
# You must `download()` an article first!
# jason-concepcion 143
# You must `download()` an article first!
# jason-concepcion 174
# Article `download()` failed with 404 Client Error: Not Found for url: http://backstorysports.com/2015/06/30/marks-picks-june/ on URL http://backstorysports.com/2015/06/30/marks-picks-june/
# tom-haberstroh 194
# You must `download()` an article first!
# nate-duncan 3
# You must `download()` an article first!
# nate-duncan 4
# You must `download()` an article first!
# nate-duncan 5
# You must `download()` an article first!
# nate-duncan 6
# You must `download()` an article first!
# zach-harper 12
# You must `download()` an article first!
# zach-harper 13
# You must `download()` an article first!
# zach-harper 14
# You must `download()` an article first!
# zach-harper 15
# You must `download()` an article first!
# zach-harper 16
# You must `download()` an article first!
# zach-harper 17
# You must `download()` an article first!
# zach-harper 18
# You must `download()` an article first!
# zach-harper 19
# You must `download()` an article first!
# zach-harper 21
# You must `download()` an article first!
# zach-harper 22
# You must `download()` an article first!
# zach-harper 23
# You must `download()` an article first!
# zach-harper 24
# You must `download()` an article first!
# zach-harper 25
# You must `download()` an article first!
# zach-harper 26
# You must `download()` an article first!
# zach-harper 28
# You must `download()` an article first!
# zach-harper 30
# You must `download()` an article first!
# zach-harper 31
# You must `download()` an article first!
# zach-harper 32
# You must `download()` an article first!
# zach-harper 33
# You must `download()` an article first!
# zach-harper 34
# You must `download()` an article first!
# zach-harper 35
# You must `download()` an article first!
# zach-harper 36
# You must `download()` an article first!
# zach-harper 37
# You must `download()` an article first!
# zach-harper 38
# You must `download()` an article first!
# zach-harper 39
# You must `download()` an article first!
# zach-harper 40
# You must `download()` an article first!
# zach-harper 41
# You must `download()` an article first!
# zach-harper 42
# You must `download()` an article first!
# zach-harper 43
# You must `download()` an article first!
# zach-harper 44
# You must `download()` an article first!
# zach-harper 45
# You must `download()` an article first!
# zach-harper 46
# You must `download()` an article first!
# zach-harper 47
# You must `download()` an article first!
# zach-harper 49
# You must `download()` an article first!
# zach-harper 50
# You must `download()` an article first!
# zach-harper 51
# You must `download()` an article first!
# zach-harper 52
# You must `download()` an article first!
# zach-harper 53
# You must `download()` an article first!
# zach-harper 54
# You must `download()` an article first!
# zach-harper 55
# You must `download()` an article first!
# zach-harper 56
# You must `download()` an article first!
# zach-harper 57
# You must `download()` an article first!
# zach-harper 58
# You must `download()` an article first!
# zach-harper 59
# You must `download()` an article first!
# zach-harper 60
# You must `download()` an article first!
# zach-harper 61
# You must `download()` an article first!
# zach-harper 62
# You must `download()` an article first!
# zach-harper 63
# You must `download()` an article first!
# zach-harper 88
# You must `download()` an article first!
# zach-harper 89
# You must `download()` an article first!
# zach-harper 90
# You must `download()` an article first!
# zach-harper 91
# You must `download()` an article first!
# zach-harper 93
# You must `download()` an article first!
# zach-harper 95
# You must `download()` an article first!
# zach-harper 96
# You must `download()` an article first!
# zach-harper 97
# You must `download()` an article first!
# zach-harper 98
# You must `download()` an article first!
# zach-harper 99
# You must `download()` an article first!
# zach-harper 100
# You must `download()` an article first!
# zach-harper 101
# You must `download()` an article first!
# zach-harper 102
# You must `download()` an article first!
# zach-harper 103
# You must `download()` an article first!
# zach-harper 104
# You must `download()` an article first!
# zach-harper 105
# You must `download()` an article first!
# zach-harper 106
# You must `download()` an article first!
# zach-harper 107
# You must `download()` an article first!
# zach-harper 108
# You must `download()` an article first!
# zach-harper 109
# You must `download()` an article first!
# zach-harper 110
# You must `download()` an article first!
# zach-harper 111
# You must `download()` an article first!
# zach-harper 112
# You must `download()` an article first!
# zach-harper 113
# You must `download()` an article first!
# zach-harper 114
# You must `download()` an article first!
# zach-harper 116
# You must `download()` an article first!
# zach-harper 117
# You must `download()` an article first!
# zach-harper 118
# You must `download()` an article first!
# zach-harper 119
# You must `download()` an article first!
# zach-harper 120
# You must `download()` an article first!
# zach-harper 121
# You must `download()` an article first!
# zach-harper 122
# You must `download()` an article first!
# zach-harper 123
# You must `download()` an article first!
# zach-harper 124
# You must `download()` an article first!
# zach-harper 125
# You must `download()` an article first!
# zach-harper 126
# You must `download()` an article first!
# zach-harper 127
# You must `download()` an article first!
# zach-harper 128
# You must `download()` an article first!
# zach-harper 129
# You must `download()` an article first!
# zach-harper 130
# You must `download()` an article first!
# zach-harper 131
# You must `download()` an article first!
# zach-harper 132
# You must `download()` an article first!
# zach-harper 133
# You must `download()` an article first!
# zach-harper 134
# You must `download()` an article first!
# zach-harper 135
# You must `download()` an article first!
# zach-harper 136
# You must `download()` an article first!
# zach-harper 137
# You must `download()` an article first!
# zach-harper 138
# You must `download()` an article first!
# zach-harper 139
# You must `download()` an article first!
# zach-harper 140
# You must `download()` an article first!
# zach-harper 141
# You must `download()` an article first!
# zach-harper 142
# You must `download()` an article first!
# zach-harper 143
# You must `download()` an article first!
# zach-harper 144
# You must `download()` an article first!
# zach-harper 145
# You must `download()` an article first!
# zach-harper 146
# You must `download()` an article first!
# zach-harper 147
# You must `download()` an article first!
# zach-harper 148
# You must `download()` an article first!
# zach-harper 149
# You must `download()` an article first!
# zach-harper 150
# You must `download()` an article first!
# zach-harper 151
# You must `download()` an article first!
# zach-harper 152
# You must `download()` an article first!
# zach-harper 153
# You must `download()` an article first!
# zach-harper 154
# You must `download()` an article first!
# zach-harper 155
# You must `download()` an article first!
# zach-harper 156
# You must `download()` an article first!
# zach-harper 157
# You must `download()` an article first!
# zach-harper 158
# You must `download()` an article first!
# zach-harper 159
# You must `download()` an article first!
# zach-harper 160
# You must `download()` an article first!
# zach-harper 161
# You must `download()` an article first!
# zach-harper 162
# You must `download()` an article first!
# zach-harper 163
# You must `download()` an article first!
# zach-harper 164
# You must `download()` an article first!
# zach-harper 165
# You must `download()` an article first!
# zach-harper 166
# You must `download()` an article first!
# zach-harper 167
# You must `download()` an article first!
# zach-harper 168
# You must `download()` an article first!
# zach-harper 169
# You must `download()` an article first!
# zach-harper 170
# You must `download()` an article first!
# zach-harper 171
# You must `download()` an article first!
# zach-harper 172
# You must `download()` an article first!
# zach-harper 173
# You must `download()` an article first!
# zach-harper 174
# You must `download()` an article first!
# zach-harper 175
# You must `download()` an article first!
# zach-harper 176
# You must `download()` an article first!
# zach-harper 177
# You must `download()` an article first!
# zach-harper 178
# You must `download()` an article first!
# zach-harper 179
# You must `download()` an article first!
# zach-harper 180
# You must `download()` an article first!
# zach-harper 181
# You must `download()` an article first!
# zach-harper 182
# You must `download()` an article first!
# zach-harper 183
# You must `download()` an article first!
# zach-harper 184
# You must `download()` an article first!
# zach-harper 185
# You must `download()` an article first!
# zach-harper 186
# You must `download()` an article first!
# zach-harper 187
# You must `download()` an article first!
# zach-harper 188
# You must `download()` an article first!
# zach-harper 189
# You must `download()` an article first!
# zach-harper 190
# You must `download()` an article first!
# zach-harper 191
# You must `download()` an article first!
# zach-harper 192
# You must `download()` an article first!
# zach-harper 193
# You must `download()` an article first!
# zach-harper 194
# You must `download()` an article first!
# zach-harper 195
# You must `download()` an article first!
# zach-harper 196
# You must `download()` an article first!
# zach-harper 197
# You must `download()` an article first!
# zach-harper 198
# You must `download()` an article first!
# sam_amick 1
# You must `download()` an article first!
# sam_amick 10
# You must `download()` an article first!
# sam_amick 18
# You must `download()` an article first!
# sam_amick 153
# You must `download()` an article first!
# sam_amick 156
# You must `download()` an article first!
# sam_amick 168
# You must `download()` an article first!
# sam_amick 169
# You must `download()` an article first!
# sam_amick 172
# You must `download()` an article first!
# sam_amick 173
# You must `download()` an article first!
# sam_amick 181
# You must `download()` an article first!
# sam_amick 189
# You must `download()` an article first!
# sam_amick 196
# You must `download()` an article first!
# david-aldridge 81
# Article `download()` failed with 503 Server Error: Service Unavailable for url: http://quibb.com/links/slack-is-killing-email?comment_id=19724 on URL http://quibb.com/links/slack-is-killing-email?comment_id=19724
# jpdabrams 156
# Article `download()` failed with 404 Client Error: Not Found for url: https://sports.yahoo.com/zach-lavine-free-agency-001838318.html on URL https://sports.yahoo.com/zach-lavine-free-agency-001838318.html
# shams-charania 41
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.stowetoday.com/stowe_reporter/news/state_news/vermont-writer-strikes-gold-with-olympic-cross-country-book/article_f4fa48e2-22ec-11e8-9a19-87aaa49e6ad4.html on URL http://www.stowetoday.com/stowe_reporter/news/state_news/vermont-writer-strikes-gold-with-olympic-cross-country-book/article_f4fa48e2-22ec-11e8-9a19-87aaa49e6ad4.html
# kevin-p-oconnor 4
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.delcotimes.com/article/dc/20171225/news/171229801/ on URL http://www.delcotimes.com/article/DC/20171225/NEWS/171229801
# kevin-p-oconnor 8
# You must `download()` an article first!
# kevin-p-oconnor 34
# Article `download()` failed with 404 Client Error: Not Found for url: https://ncadvertiser.com/74167/support-glass-houses-pz-permit-request/ on URL http://ncadvertiser.com/74167/support-glass-houses-pz-permit-request/
# kevin-p-oconnor 41
# You must `download()` an article first!
# shea-serrano 158
# You must `download()` an article first!
# ian-begley 169
# Article `download()` failed with 503 Server Error: Server Error for url: https://www.cnn.com/2015/10/08/opinions/nichols-sports-jessica-mendoza-greg-hardy/index.html on URL http://www.cnn.com/2015/10/08/opinions/nichols-sports-jessica-mendoza-greg-hardy/index.html
# rachel-nichols 8
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.ksat.com/content/pns/ksat/sports/2014/08/28/us-nfl-domestic-violence.html on URL http://www.ksat.com/content/pns/ksat/sports/2014/08/28/us-nfl-domestic-violence.html
# rachel-nichols 17
# Article `download()` failed with 503 Server Error: Server Error for url: http://www.cnn.com/2014/08/28/us/nfl-domestic-violence/index.html on URL http://www.cnn.com/2014/08/28/us/nfl-domestic-violence/index.html
# rachel-nichols 18
# You must `download()` an article first!
# ben-golliver 131
# You must `download()` an article first!
# ben-golliver 132
# You must `download()` an article first!
# ben-golliver 133
# You must `download()` an article first!
# ben-golliver 135
# You must `download()` an article first!
# ben-golliver 136
# You must `download()` an article first!
# ben-golliver 137
# You must `download()` an article first!
# ben-golliver 138
# You must `download()` an article first!
# ben-golliver 142
# You must `download()` an article first!
# ben-golliver 143
# You must `download()` an article first!
# ben-golliver 147
# You must `download()` an article first!
# ben-golliver 149
# You must `download()` an article first!
# ben-golliver 152
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2018/03/how_the_lakers_fit_into_the_landscape_of_lebron_suitors_remains_to_be_seen on URL http://www.bostonherald.com/sports/celtics/2018/03/how_the_lakers_fit_into_the_landscape_of_lebron_suitors_remains_to_be_seen
# ben-golliver 198
# You must `download()` an article first!
# mike-prada 121
# You must `download()` an article first!
# mike-prada 122
# You must `download()` an article first!
# mike-prada 174
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/why-rudy-gobert-is-the-most-valuable-big-man-in-the-nba/ on URL http://www.espn975.com/why-rudy-gobert-is-the-most-valuable-big-man-in-the-nba/
# mike-prada 190
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/are-the-cavaliers-actually-in-trouble/ on URL http://www.espn975.com/are-the-cavaliers-actually-in-trouble/
# mike-prada 192
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/how-nikola-jokic-became-the-unlikely-superstar-transforming-the-nuggets/ on URL http://www.espn975.com/how-nikola-jokic-became-the-unlikely-superstar-transforming-the-nuggets/
# mike-prada 198
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2018/01/the_early_returns_on_isaiah_thomass_return on URL http://www.bostonherald.com/sports/celtics/2018/01/the_early_returns_on_isaiah_thomass_return
# robmahoney 94
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2018/01/the_two_sides_of_ben_simmons on URL http://www.bostonherald.com/sports/celtics/2018/01/the_two_sides_of_ben_simmons
# robmahoney 96
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/nba/2017/10/18/rockets-first-look on URL https://www.si.com/nba/2017/10/18/rockets-first-look
# robmahoney 128
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2017/10/72_reasons_to_watch_the_2017_18_nba_season on URL http://www.bostonherald.com/sports/celtics/2017/10/72_reasons_to_watch_the_2017_18_nba_season
# robmahoney 131
# Article `download()` failed with 403 Client Error: Forbidden for url: https://p2pi.org/article/2017-dot-winners-announced on URL https://p2pi.org/article/2017-dot-winners-announced
# robmahoney 142
# You must `download()` an article first!
# tim-macmahon 188
# You must `download()` an article first!
# tim-macmahon 189
# You must `download()` an article first!
# tim-macmahon 190
# Article `download()` failed with 500 Server Error: Internal Server Error for url: http://www.espn.com/espn/page2/story/_/page/simmons%2F090817 on URL http://www.espn.com/espn/page2/story/_/page/simmons%2F090817
# billsimmons 65
# You must `download()` an article first!
# billsimmons 86
# You must `download()` an article first!
# billsimmons 98
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.theringer.com/the-bill-simmons-podcast/2018/3/16/17128734/the-current-state-of-college-basketball-and-democratizing-communication-with-chuck-klosterman on URL https://www.theringer.com/the-bill-simmons-podcast/2018/3/16/17128734/the-current-state-of-college-basketball-and-democratizing-communication-with-chuck-klosterman
# billsimmons 134
# You must `download()` an article first!
# jonathan-tjarks 127
# You must `download()` an article first!
# jonathan-tjarks 128
# You must `download()` an article first!
# jonathan-tjarks 129
# You must `download()` an article first!
# danny-leroux 141
# You must `download()` an article first!
# danny-leroux 142
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.thescore.com/s/5939915 on URL https://www.thescore.com/s/5939915
# chris-mannix 18
# Article `download()` failed with 404 Client Error: Not Found for url: https://sports.yahoo.com/1586963-070118726.html on URL https://sports.yahoo.com/1586963-070118726.html
# chris-mannix 142
# Article `download()` failed with 404 Client Error: Not Found for url: https://sports.vice.com/en_us/articles on URL https://sports.vice.com/en_us/articles
# michael-pina 174
# You must `download()` an article first!
# ben-falk 71
# You must `download()` an article first!
# ben-falk 72
# You must `download()` an article first!
# ben-falk 73
# You must `download()` an article first!
# ben-falk 74
# You must `download()` an article first!
# ben-falk 75
# You must `download()` an article first!
# ben-falk 76
# You must `download()` an article first!
# ben-falk 77
# You must `download()` an article first!
# ben-falk 78
# You must `download()` an article first!
# ben-falk 79
# You must `download()` an article first!
# ben-falk 80
# You must `download()` an article first!
# ben-falk 81
# You must `download()` an article first!
# ben-falk 82
# You must `download()` an article first!
# ben-falk 83
# You must `download()` an article first!
# ben-falk 84
# You must `download()` an article first!
# ben-falk 85
# You must `download()` an article first!
# ben-falk 86
# You must `download()` an article first!
# ben-falk 87
# You must `download()` an article first!
# ben-falk 88
# You must `download()` an article first!
# ben-falk 89
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.stardem.com/sports/pros/the-perception-of-loyalty-should-be-retired/article_49c04b51-3bbc-57d9-ba27-c51ac7cf6e6a.html on URL http://www.stardem.com/sports/pros/the-perception-of-loyalty-should-be-retired/article_49c04b51-3bbc-57d9-ba27-c51ac7cf6e6a.html
# tim-bontemps 97
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.yorknewstimes.com/news/trending/his-legacy-assured-lebron-james-move-to-the-lakers-is/article_d6a3b5e1-4ce1-52f5-ae22-d24207f4204f.html on URL https://www.yorknewstimes.com/news/trending/his-legacy-assured-lebron-james-move-to-the-lakers-is/article_d6a3b5e1-4ce1-52f5-ae22-d24207f4204f.html
# tim-bontemps 154
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.journalnow.com/sports/pro_sports/basketball/winners-and-losers-from-the-nba-draft/article_9477cd3f-15a2-5756-9088-e338d30c720b.html on URL https://www.journalnow.com/sports/pro_sports/basketball/winners-and-losers-from-the-nba-draft/article_9477cd3f-15a2-5756-9088-e338d30c720b.html
# tim-bontemps 184
# You must `download()` an article first!
# henry-abbott 3
# You must `download()` an article first!
# henry-abbott 4
# You must `download()` an article first!
# henry-abbott 5
# You must `download()` an article first!
# henry-abbott 6
# You must `download()` an article first!
# henry-abbott 7
# You must `download()` an article first!
# henry-abbott 8
# You must `download()` an article first!
# henry-abbott 9
# Article `download()` failed with 404 Client Error: Not Found for url: http://www
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.derekbodner.com/2017/03/31/announcement/ on URL http://www.derekbodner.com/2017/03/31/announcement/
# derek-bodner 78
# Article `download()` failed with 404 Client Error: Not Found for url: http://derekbodner.com/2017/02/09/sixers-mailbag-1-furkan-korkmaz-update-draft-prospects-and-more/ on URL http://derekbodner.com/2017/02/09/sixers-mailbag-1-furkan-korkmaz-update-draft-prospects-and-more/
# derek-bodner 90
# Article `download()` failed with 404 Client Error: Not Found for url: http://derekbodner.com/2017/02/08/does-pursuing-jrue-holiday-at-the-trade-deadline-make-sense-for-the-76ers/ on URL http://derekbodner.com/2017/02/08/does-pursuing-jrue-holiday-at-the-trade-deadline-make-sense-for-the-76ers/
# derek-bodner 91
# Article `download()` failed with 404 Client Error: Not Found for url: http://derekbodner.com/2017/02/07/pelicans-roster-jrue-holiday/ on URL http://derekbodner.com/2017/02/07/pelicans-roster-jrue-holiday/
# derek-bodner 92
# Article `download()` failed with 404 Client Error: Not Found for url: http://derekbodner.com/2017/02/06/sixers-pelicans-discussing-jahlil-okafor-trade/ on URL http://derekbodner.com/2017/02/06/sixers-pelicans-discussing-jahlil-okafor-trade/
# derek-bodner 93
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.netsdaily.com/2018/7/5/17538364/12-best-unrestricted-nba-free-agents-still-available-blopez on URL https://www.netsdaily.com/2018/7/5/17538364/12-best-unrestricted-nba-free-agents-still-available-blopez
# tom-ziller 54
# You must `download()` an article first!
# chris-ballard 75
# You must `download()` an article first!
# chris-ballard 98
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/2003/06/30/345735/the-kid-with-the-kick-high-styling-high-fiving-florida-rookie-dontrelle-willis-has-everybody-even-the-famously-indifferent-marlins-fans-talking-about-his-historic-start on URL http://www.si.com/vault/2003/06/30/345735/the-kid-with-the-kick-high-styling-high-fiving-florida-rookie-dontrelle-willis-has-everybody-even-the-famously-indifferent-marlins-fans-talking-about-his-historic-start
# chris-ballard 113
# You must `download()` an article first!
# chris-ballard 150
# You must `download()` an article first!
# chris-ballard 160
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1166984/index.htm on URL http://si.com/vault/article/magazine/MAG1166984/index.htm
# chris-ballard 161
# You must `download()` an article first!
# chris-ballard 162
# You must `download()` an article first!
# chris-ballard 163
# You must `download()` an article first!
# chris-ballard 164
# You must `download()` an article first!
# chris-ballard 165
# You must `download()` an article first!
# chris-ballard 166
# You must `download()` an article first!
# chris-ballard 167
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1194725/index.htm on URL http://si.com/vault/article/magazine/MAG1194725/index.htm
# chris-ballard 168
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1209927/1/index.htm on URL http://si.com/vault/article/magazine/MAG1209927/1/index.htm
# chris-ballard 169
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1209927/index.htm on URL http://si.com/vault/article/magazine/MAG1209927/index.htm
# chris-ballard 170
# You must `download()` an article first!
# chris-ballard 171
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.cnnsi.com/vault/article/magazine/MAG1166959/3/index.htm on URL http://www.cnnsi.com/vault/article/magazine/MAG1166959/3/index.htm
# chris-ballard 172
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1209890/index.htm on URL http://si.com/vault/article/magazine/MAG1209890/index.htm
# chris-ballard 173
# You must `download()` an article first!
# chris-ballard 174
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1209466/index.htm on URL http://si.com/vault/article/magazine/MAG1209466/index.htm
# chris-ballard 175
# You must `download()` an article first!
# chris-ballard 176
# You must `download()` an article first!
# chris-ballard 177
# You must `download()` an article first!
# chris-ballard 178
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1208954/index.htm on URL http://si.com/vault/article/magazine/MAG1208954/index.htm
# chris-ballard 179
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/vault/article/magazine/MAG1208952/index.htm on URL http://si.com/vault/article/magazine/MAG1208952/index.htm
# chris-ballard 180
# You must `download()` an article first!
# chris-ballard 181
# You must `download()` an article first!
# chris-ballard 182
# You must `download()` an article first!
# chris-ballard 183
# You must `download()` an article first!
# josh-eberley 2
# You must `download()` an article first!
# josh-eberley 3
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.todaysfastbreak.com/nba-west/dallas-mavericks/never-say-die-tale-mavericks/ on URL http://www.todaysfastbreak.com/nba-west/dallas-mavericks/never-say-die-tale-mavericks/
# josh-eberley 6
# You must `download()` an article first!
# adi-joseph 74
# You must `download()` an article first!
# adi-joseph 75
# You must `download()` an article first!
# adi-joseph 76
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.denverstiffs.com/2018/6/21/17491636/denver-nuggets-michael-porter-jr-i-had-no-talks-with-denver-entering-the-nba-draft on URL https://www.denverstiffs.com/2018/6/21/17491636/denver-nuggets-michael-porter-jr-i-had-no-talks-with-denver-entering-the-nba-draft
# adam-mares 27
# You must `download()` an article first!
# adam-mares 49
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.denverstiffs.com/2018/1/17/16901470/hang-the-dj-the-denver-nuggets-and-the-simulation-hypothesis on URL https://www.denverstiffs.com/2018/1/17/16901470/hang-the-dj-the-denver-nuggets-and-the-simulation-hypothesis
# adam-mares 113
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.denverstiffs.com/2018/1/8/16862108/new-shirt-from-d-line-co-the-garrison-denver-nuggets on URL https://www.denverstiffs.com/2018/1/8/16862108/new-shirt-from-d-line-co-the-garrison-denver-nuggets
# adam-mares 121
# You must `download()` an article first!
# sam-vecenie 114
# You must `download()` an article first!
# sam-vecenie 115
# You must `download()` an article first!
# sam-vecenie 116
# You must `download()` an article first!
# sam-vecenie 117
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2018/02/will_isaiah_thomas_become_a_long_term_fixture_in_la on URL http://www.bostonherald.com/sports/celtics/2018/02/will_isaiah_thomas_become_a_long_term_fixture_in_la
# andrew-sharp 20
# Article `download()` failed with 403 Client Error: Forbidden for url: http://www.bostonherald.com/sports/celtics/2018/02/the_cavs_future_gets_brighter_as_it_s_timeline_gets_more_depressing on URL http://www.bostonherald.com/sports/celtics/2018/02/the_cavs_future_gets_brighter_as_it_s_timeline_gets_more_depressing
# andrew-sharp 22
# You must `download()` an article first!
# andrew-sharp 36
# You must `download()` an article first!
# andrew-sharp 44
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.si.com/nba/2016/06/24/nba-draft-thunder-celtics-76ers-serge-ibaka-jimmy%20butler-podcast on URL http://www.si.com/nba/2016/06/24/nba-draft-thunder-celtics-76ers-serge-ibaka-jimmy%20butler-podcast
# andrew-sharp 81
# You must `download()` an article first!
# david-thorpe 3
# You must `download()` an article first!
# david-thorpe 42
# You must `download()` an article first!
# royce-webb 0
# You must `download()` an article first!
# ericpincus 0
# You must `download()` an article first!
# ericpincus 1
# You must `download()` an article first!
# paul-flannery 52
# You must `download()` an article first!
# paul-flannery 62
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/bucks-could-be-spoilers-in-nba-playoffs/ on URL http://www.espn975.com/bucks-could-be-spoilers-in-nba-playoffs/
# paul-flannery 137
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/the-giannis-antetokounmpo-dream-becomes-reality/ on URL http://www.espn975.com/the-giannis-antetokounmpo-dream-becomes-reality/
# paul-flannery 140
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/theres-trouble-with-the-nbas-dnp-rest-trend/ on URL http://www.espn975.com/theres-trouble-with-the-nbas-dnp-rest-trend/
# paul-flannery 143
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/the-nba-playoff-race-at-the-bottom-of-the-eastern-conference-is-getting-interesting/ on URL http://www.espn975.com/the-nba-playoff-race-at-the-bottom-of-the-eastern-conference-is-getting-interesting/
# paul-flannery 147
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/how-to-enjoy-march-madness-as-an-nba-partisan/ on URL http://www.espn975.com/how-to-enjoy-march-madness-as-an-nba-partisan/
# paul-flannery 149
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/kawhi-leonard-vaults-himself-into-the-nba-mvp-conversation/ on URL http://www.espn975.com/kawhi-leonard-vaults-himself-into-the-nba-mvp-conversation/
# paul-flannery 151
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/what-its-like-to-play-with-lebron-james/ on URL http://www.espn975.com/what-its-like-to-play-with-lebron-james/
# paul-flannery 152
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn975.com/the-nba-trade-deadline-was-defined-by-unintended-consequences/ on URL http://www.espn975.com/the-nba-trade-deadline-was-defined-by-unintended-consequences/
# paul-flannery 155
# You must `download()` an article first!
# timkawakami 21
# You must `download()` an article first!
# timkawakami 22
# You must `download()` an article first!
# timkawakami 23
# You must `download()` an article first!
# timkawakami 24
# You must `download()` an article first!
# timkawakami 25
# You must `download()` an article first!
# timkawakami 26
# You must `download()` an article first!
# keith-smith 54
# You must `download()` an article first!
# keith-smith 55
# You must `download()` an article first!
# keith-smith 56
# You must `download()` an article first!
# keith-smith 57
# You must `download()` an article first!
# keith-smith 62
# You must `download()` an article first!
# keith-smith 63
# You must `download()` an article first!
# keith-smith 64
# You must `download()` an article first!
# keith-smith 65
# You must `download()` an article first!
# keith-smith 66
# You must `download()` an article first!
# keith-smith 67
# You must `download()` an article first!
# keith-smith 68
# You must `download()` an article first!
# keith-smith 69
# You must `download()` an article first!
# keith-smith 70
# You must `download()` an article first!
# keith-smith 71
# You must `download()` an article first!
# keith-smith 73
# You must `download()` an article first!
# keith-smith 74
# You must `download()` an article first!
# keith-smith 75
# You must `download()` an article first!
# keith-smith 76
# You must `download()` an article first!
# keith-smith 77
# You must `download()` an article first!
# keith-smith 78
# You must `download()` an article first!
# keith-smith 79
# You must `download()` an article first!
# keith-smith 80
# You must `download()` an article first!
# keith-smith 81
# You must `download()` an article first!
# keith-smith 82
# You must `download()` an article first!
# keith-smith 83
# You must `download()` an article first!
# keith-smith 84
# You must `download()` an article first!
# keith-smith 85
# You must `download()` an article first!
# keith-smith 87
# You must `download()` an article first!
# keith-smith 88
# You must `download()` an article first!
# keith-smith 89
# You must `download()` an article first!
# keith-smith 90
# You must `download()` an article first!
# keith-smith 91
# You must `download()` an article first!
# keith-smith 93
# You must `download()` an article first!
# keith-smith 94
# You must `download()` an article first!
# keith-smith 95
# You must `download()` an article first!
# keith-smith 96
# You must `download()` an article first!
# keith-smith 97
# You must `download()` an article first!
# keith-smith 98
# You must `download()` an article first!
# keith-smith 99
# You must `download()` an article first!
# keith-smith 100
# You must `download()` an article first!
# keith-smith 101
# You must `download()` an article first!
# keith-smith 102
# You must `download()` an article first!
# keith-smith 103
# You must `download()` an article first!
# keith-smith 104
# You must `download()` an article first!
# keith-smith 105
# You must `download()` an article first!
# keith-smith 106
# You must `download()` an article first!
# keith-smith 107
# You must `download()` an article first!
# keith-smith 108
# You must `download()` an article first!
# keith-smith 109
# You must `download()` an article first!
# keith-smith 110
# You must `download()` an article first!
# keith-smith 111
# You must `download()` an article first!
# keith-smith 112
# You must `download()` an article first!
# keith-smith 113
# You must `download()` an article first!
# keith-smith 114
# You must `download()` an article first!
# keith-smith 115
# You must `download()` an article first!
# keith-smith 116
# You must `download()` an article first!
# keith-smith 117
# You must `download()` an article first!
# keith-smith 118
# You must `download()` an article first!
# keith-smith 119
# You must `download()` an article first!
# keith-smith 120
# You must `download()` an article first!
# keith-smith 121
# You must `download()` an article first!
# keith-smith 122
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-celtics-squeak-cavaliers-rockets-rain-triples-clippers/ on URL http://www.fanragsports.com/nba/nba-yesterday-celtics-squeak-cavaliers-rockets-rain-triples-clippers/
# keith-smith 123
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-hawks-roll-past-celtics-howard-ejection-derozan-lifts-raps-knicks/ on URL http://www.fanragsports.com/nba/nba-yesterday-hawks-roll-past-celtics-howard-ejection-derozan-lifts-raps-knicks/
# keith-smith 124
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-playoff-contenders-hold-off-rallies-to-pick-up-wins/ on URL http://www.fanragsports.com/nba/nba-yesterday-playoff-contenders-hold-off-rallies-to-pick-up-wins/
# keith-smith 125
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-team-banana-boat-posts-big-night/ on URL http://www.fanragsports.com/nba/nba-yesterday-team-banana-boat-posts-big-night/
# keith-smith 126
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-raptors-come-behind-spurs-handle-clippers/ on URL http://www.fanragsports.com/nba/nba-yesterday-raptors-come-behind-spurs-handle-clippers/
# keith-smith 127
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-rockets-roll-new-orleans-warriors-sink-clippers/ on URL http://www.fanragsports.com/nba/nba-yesterday-rockets-roll-new-orleans-warriors-sink-clippers/
# keith-smith 128
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-all-star-weekend-wrap/ on URL http://www.fanragsports.com/nba/nba-yesterday-all-star-weekend-wrap/
# keith-smith 129
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-bulls-snatch-victory-jaws-defeat-questionable-call/ on URL http://www.fanragsports.com/nba/nba-yesterday-bulls-snatch-victory-jaws-defeat-questionable-call/
# keith-smith 130
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-westbrook-gets-another-triple-double-knicks/ on URL http://www.fanragsports.com/nba/nba-yesterday-westbrook-gets-another-triple-double-knicks/
# keith-smith 131
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-butler-leads-bulls-11th-straight-win-raptors/ on URL http://www.fanragsports.com/nba/nba-yesterday-butler-leads-bulls-11th-straight-win-raptors/
# keith-smith 132
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-nuggets-stun-warriors-denver/ on URL http://www.fanragsports.com/nba/nba-yesterday-nuggets-stun-warriors-denver/
# keith-smith 133
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-knicks-upset-spurs-pistons-come-back-toronto/ on URL http://www.fanragsports.com/nba/nba-yesterday-knicks-upset-spurs-pistons-come-back-toronto/
# keith-smith 135
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-kevin-durant-shines-emotional-return-okc/ on URL http://www.fanragsports.com/nba/nba-yesterday-kevin-durant-shines-emotional-return-okc/
# keith-smith 136
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday-wizards-top-pacers-green-gets-historic-triple-double/ on URL http://www.fanragsports.com/nba/nba-yesterday-wizards-top-pacers-green-gets-historic-triple-double/
# keith-smith 137
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.fanragsports.com/nba/nba-yesterday
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.tematicaresearch.com/2016/07/15/the-cashless-consumption-battle-is-a-crowded-one-good-news-for-us-mc-wmt-aapl-v-wmt-wfc/ on URL https://www.tematicaresearch.com/2016/07/15/the-cashless-consumption-battle-is-a-crowded-one-good-news-for-us-mc-wmt-aapl-v-wmt-wfc/
# chris_broussard 75
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.tematicaresearch.com/2016/07/14/professional-sports-teams-recruiting-and-signing-video-gamers-to-contracts-ea/ on URL https://www.tematicaresearch.com/2016/07/14/professional-sports-teams-recruiting-and-signing-video-gamers-to-contracts-ea/
# chris_broussard 76
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.tematicaresearch.com/2016/07/14/masterpass-expansion-by-ma-reflects-the-growth-of-cashless-consumption-thematic/ on URL https://www.tematicaresearch.com/2016/07/14/masterpass-expansion-by-ma-reflects-the-growth-of-cashless-consumption-thematic/
# chris_broussard 77
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.tematicaresearch.com/2016/07/11/experience-driven-shopping-and-entertainment-redefining-the-american-shopping-mall/ on URL https://www.tematicaresearch.com/2016/07/11/experience-driven-shopping-and-entertainment-redefining-the-american-shopping-mall/
# chris_broussard 78
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.tematicaresearch.com/2016/06/14/experience-economy-now-at-your-local-grocery-store/ on URL https://www.tematicaresearch.com/2016/06/14/experience-economy-now-at-your-local-grocery-store/
# chris_broussard 82
# Article `download()` failed with 404 Client Error: Not Found for url: http://www.espn.com/espn/now?nowId=21-0530842043048533843-4 on URL http://espn.go.com/espn/now?nowId=21-0530842043048533843-4
# chris_broussard 83
# Article `download()` failed with 404 Client Error: Not Found for url: https://www.tematicaresearch.com/thematic-signals/2015/10/another-nail-in-the-password-coffin/ on URL http://thematicsignals.com/2015/10/another-nail-in-the-password-coffin/
# chris_broussard 97
# tevin-williams 1
# tevin-williams 2
# tevin-williams 3
# tevin-williams 4
# tevin-williams 5
# tevin-williams 6
# You must `download()` an article first!
# tevin-williams 7
# You must `download()` an article first!
# tevin-williams 8
# You must `download()` an article first!
# tevin-williams 9
# You must `download()` an article first!
# tevin-williams 10
# tevin-williams 11
# tevin-williams 12
# tevin-williams 13
# tevin-williams 14
# tevin-williams 15
# tevin-williams 16
# tevin-williams 17
# tevin-williams 18
# tevin-williams 19
# tevin-williams 20
# tevin-williams 21
# tevin-williams 22
# tevin-williams 23
# tevin-williams 24
# tevin-williams 25
# tevin-williams 26
# tevin-williams 27
# tevin-williams 28
# tevin-williams 29
# tevin-williams 30
# ti-windisch 0
# ti-windisch 1
# ti-windisch 2
# ti-windisch 3
# ti-windisch 4
# ti-windisch 5
# You must `download()` an article first!
# ti-windisch 6
# You must `download()` an article first!
# ti-windisch 7
# You must `download()` an article first!
# ti-windisch 8
# You must `download()` an article first!
# ti-windisch 9
# You must `download()` an article first!
# ti-windisch 10
# You must `download()` an article first!
# ti-windisch 11
# You must `download()` an article first!
# ti-windisch 12
# You must `download()` an article first!
# ti-windisch 13
# You must `download()` an article first!
# ti-windisch 14
# You must `download()` an article first!
# ti-windisch 15
# You must `download()` an article first!
# ti-windisch 16
# You must `download()` an article first!
# ti-windisch 17
# You must `download()` an article first!
# ti-windisch 18
# You must `download()` an article first!
# ti-windisch 19
# ti-windisch 20
# ti-windisch 21
# ti-windisch 22
# stephen-a-smith 29
# You must `download()` an article first!
# stephen-a-smith 30
# You must `download()` an article first!
# stephen-a-smith 31
# stephen-a-smith 32
# stephen-a-smith 33
# stephen-a-smith 34
# stephen-a-smith 35
# stephen-a-smith 36
# stephen-a-smith 37
# stephen-a-smith 38
# stephen-a-smith 39
# stephen-a-smith 40
# stephen-a-smith 41
# stephen-a-smith 42
# stephen-a-smith 43
# stephen-a-smith 44
# stephen-a-smith 45
# stephen-a-smith 46
# stephen-a-smith 47
# stephen-a-smith 48
# stephen-a-smith 49
# stephen-a-smith 50
# stephen-a-smith 51
# stephen-a-smith 52
# stephen-a-smith 53
# stephen-a-smith 54
# stephen-a-smith 55
# stephen-a-smith 56
# stephen-a-smith 57
# stephen-a-smith 58
# andré-voigt 0
# Article `download()` failed with 404 Client Error: Not Found for url: https://terezowens.com/kevin-hart-confronts-skip-bayless-over-his-labron-james-hatred-video/ on URL https://terezowens.com/kevin-hart-confronts-skip-bayless-over-his-labron-james-hatred-video/
# skip-bayless 0
# skip-bayless 1
# skip-bayless 2
# skip-bayless 3
# skip-bayless 4
# skip-bayless 5
# skip-bayless 6
# skip-bayless 7
# skip-bayless 8
# skip-bayless 9
# skip-bayless 10
# skip-bayless 11
# skip-bayless 12
# skip-bayless 13
# skip-bayless 14
# skip-bayless 15
# skip-bayless 16
# skip-bayless 17
# skip-bayless 18
# skip-bayless 19
# skip-bayless 20
# skip-bayless 21
# skip-bayless 22
# skip-bayless 23

# %%
sys.getsizeof(article.text)
# Out:
# 4402

# %%
# try analyzing data
client = MongoClient()
mydb = client["testinsightdb"]

# %%
mycol = mydb['zachlowe_nba']
print(mycol)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'testinsightdb'), 'skip-bayless')

# %%
y = mycol.find_one({"name": 'zachlowe_nba'})
print(y['article'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-08b1ff442a0d> in <module>()
#       1 y = mycol.find_one({"name": 'zachlowe_nba'})
# ----> 2 print(y['article'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# y = mycol.find_one({"name": 'zachlowe_nba'})
tmpcol = mydb['zachlowe_nba']
y = tmpcol.find({"name": 'zachlowe_nba'})

# %%
y[2]
# Out:
# {'_id': ObjectId('5b9c705f11919a2b1a15c30f'),
#  'name': 'zachlowe_nba',
#  'article_url': 'http://www.espn.com/nba/story/_/id/24191536/zach-lowe-jimmy-butler-blake-griffin-nba-supermax',
#  'article_source': 'espn.com',
#  'pubdates': '2018-07-27T10:53:22',
#  'writer_id': 693716,
#  'article': 'Jimmy Butler in June 2017 fell right into the nebulous region where debating a maximum or new supermaximum contract becomes especially fraught for teams.\n\nWith another All-NBA berth the next season (2017-18), Butler would qualify for a five-year, $220 million supermax -- vaulting to a salary equivalent to 35 percent of the salary cap, 5 percentage points more than normal for a player at his experience level. The difference would amount to $25 million or more over the full deal. Add annual 8 percent raises that might outpace growth in the cap, and such a deal could soak up 40 percent of a team\'s cap space on the back end. It is as large a commitment as exists in the NBA.\n\nButler was the only star on a mediocre team. Without finding a second, and perhaps a third, the Bulls would go nowhere interesting during the length of Butler\'s supermax. The sheer size of his deal could make luring those stars harder.\n\nButler was about to turn 28. Depending on your taste, he at that point was somewhere between the eighth- and 12th-best player in the league. You do the supermax for a healthy top-five-ish guy in that age range without thinking; supermaxes for James Harden and Stephen Curry are no-brainers. Ditto for the deals with which Milwaukee and New Orleans hope to eventually retain Giannis Antetokounmpo and Anthony Davis, respectively. You shouldn\'t do it for the 20th-best player. In between? That\'s where it gets hard.\n\nButler carried Tom Thibodeau miles on his knees. A five-year deal would take Butler into the downslope of his career. Everyone knows a five-year max for a 33-year-old is probably going to end badly. The Rockets coaxed Chris Paul, 33, into a shorter four-year deal, and must still fear the projected bang-for-the-buck in Years 3 and 4.\n\nBut what about for a 28-year-old?\n\nChicago bailed out, and dealt Butler -- plus the 16th pick in the 2017 draft -- for three unproven players and the chance to bottom out for a high pick in the 2018 draft. It was icy in its rationality. It is unclear if it will pay off -- if Chicago\'s next half-decade-plus with Kris Dunn, Zach LaVine, Lauri Markkanen, Wendell Carter Jr., Jabari Parker, and perhaps another high pick in 2019 will produce more wins, and a better chance at title contention, than the same period with Butler, Nikola Mirotic, a few mid-first-round picks and some cap space. Editor\'s Picks Lowe: Just how good can these young Bulls become? Can the Bulls find a star and break through, or do they have a hard ceiling? Zach Lowe looks at the future in Chicago.\n\nLowe: Jenny Boucek\'s pregnancy represents a first for the NBA As a pregnant coach, the Mavericks\' assistant is breaking new ground in the league, and she talks to ESPN. 1 Related\n\nIt is the kind of intentional step back more teams seem comfortable making -- and one a majority of executives around the league consider appropriate, if painful.\n\nReducing the length of contracts in the last two collective bargaining agreements has accelerated the timing of those decisions. Stars reach their third contracts, the pivot point which tests commitment between player and team, earlier than they used to -- before they even turn 30.\n\nChicago cut bait on the Butler era. The Kings wanted no part of a supermax for DeMarcus Cousins. Some within the Pacers had qualms about a supermax for Paul George, sources say -- a dilemma that never came to pass, since George did not make an All-NBA team in 2017 before Indiana traded him.\n\nThe Clippers re-signed Blake Griffin, then 28 and their first homegrown star in decades, to a regular 30 percent max -- and traded him at the first opportunity for Tobias Harris, Avery Bradley on an expiring contract and a pick at the back of the lottery. We hailed it as a victory for LA.\n\nJohn Wall (27) and Russell Westbrook (29) will earn almost $50 million toward the end of their supermax deals. Both have multiple knee surgeries in the rearview. There is a real chance that one or bot ...
#  'authors': ['Zach Lowe', 'Chris Forsberg', 'Royce Young', 'Jackie Macmullan'],
#  'narticle': 2,
#  'article_summary': ''}

# %%
with open('/Users/rohanramesh/Documents/Insight/data_bball_writers/TestArticleSave.json', 'w') as outfile:
    json.dump(article, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b1727a4175d5> in <module>()
#       1 with open('/Users/rohanramesh/Documents/Insight/data_bball_writers/TestArticleSave.json', 'w') as outfile:
# ----> 2     json.dump(article, outfile)
#
# /anaconda3/envs/insight_new/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /anaconda3/envs/insight_new/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# /anaconda3/envs/insight_new/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'Article' is not JSON serializable

# %%
print(article.publish_date)
# Out:
# None
